# %% [markdown]
# ## ***Python OOPs Questions***

# %% [markdown]
# Q-1>> What is Object-Oriented Programming (OOP)?
#
# ans>> Object-Oriented Programming is a programming paradigm that organizes code into objects — self-contained units that combine data (attributes) and behaviour (methods). OOP models real-world entities using classes and objects, and emphasizes concepts such as encapsulation, abstraction, inheritance and polymorphism to create reusable, modular and maintainable code.

# %% [markdown]
# Q-2>>What is a class in OOP?
#
# Ans>> A class is a blueprint or template that defines the structure and behaviour (attributes and methods) of objects. It specifies what data the objects will hold and what operations can be performed.

# %% [markdown]
# Q_3>> What is an object in OOP?
#
# Ans>>An object is an instance of a class. It is a concrete entity that has state (attribute values) and behaviour (methods) as defined by its class.

# %% [markdown]
# Q-4>>  What is the difference between abstraction and encapsulation?
#
# Ans>> Abstraction hides complex implementation details and exposes only the essential features to the user (e.g., using a Car interface drive() without showing engine internals).
#
# Encapsulation bundles data and methods together and restricts direct access to an object’s internal state (e.g., using private attributes and getters/setters). Abstraction is about what an object does; encapsulation is about how access to its data is controlled.

# %% [markdown]
# Q-5>>  What are dunder methods in Python?
#
# ans>>“Dunder” (double underscore) methods are special built-in methods with names like __init__, __str__, __add__. They let you customize object creation, representation, operator behavior, attribute access, and more. They are called by Python in special situations (construction, printing, arithmetic, etc.).

# %% [markdown]
# Q-6>> Explain the concept of inheritance in OOP.
#
# ans>>Inheritance allows a class (child/derived) to acquire attributes and methods from another class (parent/base). This promotes code reuse and enables hierarchical relationships — the child can extend or override parent behaviour.

# %% [markdown]
# Q-7>> What is polymorphism in OOP?
#
# Ans>>Polymorphism means “many forms” — the same operation or method name can work on different types or classes. For example, different classes can implement a speak() method and calling speak() on objects will execute class-specific behaviour. Polymorphism enables flexible and extensible code.

# %% [markdown]
# Q-8>>How is encapsulation achieved in Python?
#
# Ans>>Encapsulation in Python is typically achieved by:
#
# Using naming conventions (_protected, __private name mangling) to discourage direct access;
#
# Providing getter/setter methods or using @property decorators to control access and validation;
#
# Keeping implementation details hidden and exposing a clean public API.

# %% [markdown]
# Q-9>> What is a constructor in Python?
#
# Ans>>A constructor is a special method used to initialize a new object. In Python the constructor is __init__(self, ...). It sets initial attribute values when an object is created.

# %% [markdown]
# Q-10>>What are class and static methods in Python?
#
# Ans>> @classmethod methods receive the class (cls) as the first parameter and can access/modify class state.
#
# @staticmethod methods don’t receive self or cls; they behave like plain functions placed inside a class namespace (useful for utility functions related to the class).

# %% [markdown]
# Q-11>>What is method overloading in Python?
#
# Ans>>Python does not support compile-time method overloading the way Java/C++ do (multiple methods with same name but different signatures). You can simulate overloading by using default arguments, variable arguments (*args, **kwargs), or by type-checking inside a single method.

# %% [markdown]
# Q-12>>What is method overriding in OOP?
#
# Ans>>Method overriding occurs when a subclass provides its own implementation of a method that already exists in its parent class. When called on a subclass instance, the subclass version replaces the parent’s behavior.

# %% [markdown]
# Q-13>>What is a property decorator in Python?
#
# Ans>>@property turns a method into a getter for a computed attribute, allowing attribute-style access while keeping control. Combined with @<prop>.setter and @<prop>.deleter it enables controlled read/write/delete behavior for attri

# %% [markdown]
# Q-14>>Why is polymorphism important in OOP?
#
# Ans>>Polymorphism improves code flexibility and extensibility. It lets different classes be used through the same interface, simplifies code that operates on diverse objects, and supports open/closed design (you can add new types without changing client code).

# %% [markdown]
# Q-15>>What is an abstract class in Python?
#
# Ans>>An abstract class (from abc module) can define abstract methods (declared but not implemented). Concrete subclasses must implement these methods. Abstract classes provide a common interface and partial implementation while preventing direct instantiation.

# %% [markdown]
# Q-16>>What are the advantages of OOP?
#
# Ans>>Key advantages: modularity, code reuse via inheritance, easier maintenance, encapsulation of state and behavior, better mapping to real-world domains, improved readability and extensibility.

# %% [markdown]
# Q-17>>What is the difference between a class variable and an instance variable?
#
# Ans>>**Class variable is** shared across all instances of the class (declared at class level).
#
# **Instance variable ** is unique to each object (typically set in __init__ via self.attr). Changes to class

# %% [markdown]
# Q-18>>What is multiple inheritance in Python?
#
# Ans>>Multiple inheritance is when a class inherits from more than one parent class (e.g., class C(A, B):). Python supports it and resolves method order using MRO (Method Resolution Order) to determine which parent method to call.

# %% [markdown]
# Q-19>>Explain the purpose of __str__ and __repr__ methods in Python.
#
# Ans>>__str__(self) returns a human-friendly string representation (used by print() and str()).
#
# __repr__(self) should return an unambiguous representation, ideally one that could be used to recreate the object (used in the interpreter and for debugging). If only one is implemented, __repr__ is used as fallback.

# %% [markdown]
# Q-20>>What is the significance of the super() function in Python?
#
# Ans>>super() returns a proxy object that allows you to call methods from a parent class. It’s commonly used to extend or reuse parent class initialization (super().__init__()) and to support cooperative multiple inheritance.

# %% [markdown]
# Q-21>>What is the significance of the __del__ method in Python?
#
# Ans>>__del__(self) is a destructor called when an object is about to be destroyed (when reference count goes to zero or during garbage collection). It can be used to release external resources, but its use is discouraged for critical cleanup because timing of __del__ is not deterministic; using context managers is preferred.

# %% [markdown]
# Q-22>>What is the difference between @staticmethod and @classmethod in Python?
#
# ANS>>@staticmethod: no automatic self or cls parameter; it behaves like a regular function inside the class namespace.
#
# @classmethod: receives the class (cls) as first parameter and can access/modify class-level data. Use classmethod for factory methods or operations that affect the class rather than instances.

# %% [markdown]
# Q-23>>How does polymorphism work in Python with inheritance?
#
# ANS>>Polymorphism in Python uses a common method name implemented by different classes (often through inheritance or interfaces/abstract bases). When calling a method on an instance, Python resolves the method by type (MRO) and calls the appropriate class implementation, allowing different behavior for objects used interchangeably.

# %% [markdown]
# Q-24>>What is method chaining in Python OOP?
#
# ANS>>Method chaining is a style where methods return self (the object) so multiple method calls can be chained together, e.g., obj.set_x(1).set_y(2).save(). It provides concise, fluent-style APIs.

# %% [markdown]
# Q-25>>What is the purpose of the __call__ method in Python?
#
# ANS>>__call__(self, ...) makes an instance callable like a function: obj(args) invokes obj.__call__(args). It’s useful for creating function-like objects, stateful callbacks, or objects that behave like functions.

# %% [markdown]
# # ***PRACTICAL QUESTIONS***

# %%
#Q-1>>1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound")

# Child class overriding the method
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example
a = Animal()
a.speak()   # Calls parent method

d = Dog()
d.speak()   # Calls overridden method
# Out:
# This animal makes a sound
# Bark!

# %%
#Q-2>>2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Example
c = Circle(5)
print("Area of Circle:", c.area())

r = Rectangle(4, 6)
print("Area of Rectangle:", r.area())
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24

# %%
#Q-3>> Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute

# Base class
class Vehicle:
    def __init__(self, v_type):
        self.type = v_type

    def show_type(self):
        print("Vehicle Type:", self.type)

# Derived class Car
class Car(Vehicle):
    def __init__(self, v_type, brand):
        super().__init__(v_type)
        self.brand = brand

    def show_car(self):
        print("Car Brand:", self.brand)

# Further derived class ElectricCar
class ElectricCar(Car):
    def __init__(self, v_type, brand, battery_capacity):
        super().__init__(v_type, brand)
        self.battery = battery_capacity

    def show_details(self):
        self.show_type()
        self.show_car()
        print("Battery Capacity:", self.battery, "kWh")


# Example
e = ElectricCar("Four-Wheeler", "Tesla", 85)
e.show_details()
# Out:
# Vehicle Type: Four-Wheeler
# Car Brand: Tesla
# Battery Capacity: 85 kWh

# %%
#Q_4>>4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.

# Base class
class Bird:
    def fly(self):
        print("Birds can fly in general")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high in the sky")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead")

# Demonstrating polymorphism
birds = [Sparrow(), Penguin()]

for b in birds:
    b.fly()   # Calls the respective overridden method
# Out:
# Sparrow can fly high in the sky
# Penguins cannot fly, they swim instead

# %%
# Q-5>> Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance   # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")


# Example
account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited: 500
# Withdrew: 300
# Current Balance: 1200

# %%
# Q-6>> Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("Instrument is playing music")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano keys")

# Runtime polymorphism demonstration
instruments = [Guitar(), Piano()]

for i in instruments:
    i.play()   # Calls the overridden method at runtime
# Out:
# Strumming the guitar
# Playing the piano keys

# %%
# Q-7>> Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Example
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#Q-8>>Implement a class Person with a class method to count the total number of persons created.

class Person:
    # A class variable to keep track of the total number of Person objects created.
    # It's initialized to 0.
    total_persons = 0

    def __init__(self, name):
        """
        Initializes a new Person object.

        Args:
            name (str): The name of the person.
        """
        self.name = name
        # We increment the class variable 'total_persons' every time a new Person object is created.
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        """
        A class method that returns the total number of Person objects created.

        Args:
            cls: The class itself (Person in this case).

        Returns:
            int: The total count of persons.
        """
        return cls.total_persons

# ---

# Example Usage:

# Create a few Person objects.
person1 = Person("Alice")
person2 = Person("Bob")
person3 = Person("Charlie")

# Now, use the class method to get the total count.
total_count = Person.get_total_persons()
print(f"The total number of persons created is: {total_count}")
# Out:
# The total number of persons created is: 3

# %%
#Q-9>>Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator

class Fraction:
    def __init__(self, numerator, denominator):
        # prevent denominator = 0
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)
print(f2)
# Out:
# 3/4
# 7/2

# %%
#Q-10>> Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# %%
#Q-11>>Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old")

# %%
# Q-12>> mplement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# %%
#Q_13>> Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
#Q_14>>Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary

class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# %%
#Q_!5>> Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example usage
p = Product("Laptop", 50000, 2)
print(f"Total price of {p.name} is: {p.total_price()}")
# Output: Total price of Laptop is: 100000
# Out:
# Total price of Laptop is: 100000

# %%
#Q_16>> Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        print("Moo")


class Sheep(Animal):
    def sound(self):
        print("Baa")


# Example usage
c = Cow()
s = Sheep()

c.sound()
s.sound()
# Out:
# Moo
# Baa

# %%
#Q_17>>Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"


# Example usage
b = Book("To Kill a Mockingbird", "Harper Lee", 1960)
print(b.get_book_info())
# Out:
# Title: To Kill a Mockingbird, Author: Harper Lee, Year Published: 1960

# %%
#Q-18>> Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# Example usage
h = House("123 Main St", 500000)
m = Mansion("456 Luxury Ave", 2000000, 10)

print(f"House: {h.address}, Price: {h.price}")
print(f"Mansion: {m.address}, Price: {m.price}, Rooms: {m.number_of_rooms}")
# Out:
# House: 123 Main St, Price: 500000
# Mansion: 456 Luxury Ave, Price: 2000000, Rooms: 10
